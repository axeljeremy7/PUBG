# %%
# Importing the libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import random
random.seed(7)

# %%
# Checking your working directory
os.getcwd() # #os.chdir("PATH")
# Out:
# '/Users/axeljeremy/Google Drive/STAT-5850/TermProject/WorkDir/PUBG'

# %% [markdown]
# # Exploring the dataset

# %%
train_dataset = pd.read_csv('./all/train_V2.csv')
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
# Id                 object
# groupId            object
# matchId            object
# assists            int64
# boosts             int64
# damageDealt        float64
# DBNOs              int64
# headshotKills      int64
# heals              int64
# killPlace          int64
# killPoints         int64
# kills              int64
# killStreaks        int64
# longestKill        float64
# matchDuration      int64
# matchType          object
# maxPlace           int64
# numGroups          int64
# rankPoints         int64
# revives            int64
# rideDistance       float64
# roadKills          int64
# swimDistance       float64
# teamKills          int64
# vehicleDestroys    int64
# walkDistance       float64
# weaponsAcquired    int64
# winPoints          int64
# winPlacePerc       float64
# dtypes: float64(6), int64(19), object(4)
# memory usage: 983.9+ MB

# %%
train_dataset1 = train_dataset.copy()

# %%
train_dataset.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace      ...       revives  \
# 0         0.00      0              0      0         60      ...             0
# 1        91.47      0              0      0         57      ...             0
# 2        68.00      0              0      0         47      ...             0
# 3        32.90      0              0      0         75      ...             0
# 4       100.00      0              0      0         45      ...             0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# ...

# %%
train_dataset.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06   4.446966e+06
# mean   2.338149e-01  1.106908e+00  1.307171e+02  6.578755e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06
# mean   1.370147e+00  4.759935e+01  5.050060e+02  9.247833e-01  5.439551e-01
# ...

# %%
train_dataset.shape
# Out:
# (4446966, 29)

# %%
print(train_dataset.columns.values) #print(dataset.columns)
# Out:
# ['Id' 'groupId' 'matchId' 'assists' 'boosts' 'damageDealt' 'DBNOs'
#  'headshotKills' 'heals' 'killPlace' 'killPoints' 'kills' 'killStreaks'
#  'longestKill' 'matchDuration' 'matchType' 'maxPlace' 'numGroups'
#  'rankPoints' 'revives' 'rideDistance' 'roadKills' 'swimDistance'
#  'teamKills' 'vehicleDestroys' 'walkDistance' 'weaponsAcquired'
#  'winPoints' 'winPlacePerc']

# %%
# Don't run the following snippet unless you know what you are doing
# train_dataset['matchId'] = train_dataset['matchId'].astype('category')#don't run
# train_dataset['groupId'] = train_dataset['groupId'].astype('category')#don't run
# train_dataset['matchType'] = train_dataset['matchType'].astype('category')#don't run
# train_dataset['Id'] = train_dataset['Id'].astype('category')#don't run

# %% [markdown]
# ## Removing NAs
# I am assuming that the data is already clean, but only NAs values still exists.

# %%
train_dataset1 = train_dataset1.dropna()

# %%
num_rows = train_dataset1.shape[0]
num_cols = train_dataset1.shape[1]
print(train_dataset.shape)
print(num_rows, num_cols)
print()
# Out:
# (4446966, 29)
# 4446965 29

# %% [markdown]
# The dataset has only lost one column.

# %% [markdown]
# ## Analysis of each predictor

# %% [markdown]
# ### Kills

# %%
plt.title('Correlation between winPlacePerc and other Independent Variable')
train_dataset1.corr()['winPlacePerc'].sort_values().plot(kind='barh',figsize=(10,8))

# %%
train_dataset1['kills'].describe()
# Out:
# count    4.446965e+06
# mean     9.247835e-01
# std      1.558445e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      7.200000e+01
# Name: kills, dtype: float64

# %%
print("The average person kills {:.7f} players.".format(train_dataset1['kills'].mean()))
print("The median person kills {:.7f} players.".format(train_dataset1['kills'].median()))
print("The most kills ever recorded is {}.".format(train_dataset1['kills'].max()))
print("The least kills ever recorded is {}.".format(train_dataset1['kills'].min()))
# Out:
# The average person kills 0.9247835 players.
# The median person kills 0.0000000 players.
# The most kills ever recorded is 72.
# The least kills ever recorded is 0.

# %%
print("15% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.15)))
print("25% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.25)))
print("50% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.5)))
print("65% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.65)))
print("75% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.75)))
print("85% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.85)))
print("95% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.95)))
print("99% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.99)))
print("99.7% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.997)))
print("99.8% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.998)))
print("99.9% of people have {} kills or less.".format(train_dataset1['kills'].quantile(0.999)))
# Out:
# 15% of people have 0.0 kills or less.
# 25% of people have 0.0 kills or less.
# 50% of people have 0.0 kills or less.
# 65% of people have 1.0 kills or less.
# 75% of people have 1.0 kills or less.
# 85% of people have 2.0 kills or less.
# 95% of people have 4.0 kills or less.
# 99% of people have 7.0 kills or less.
# 99.7% of people have 9.0 kills or less.
# 99.8% of people have 10.0 kills or less.
# 99.9% of people have 12.0 kills or less.

# %%
data = train_dataset1.copy()
data.loc[data['kills'] > data['kills'].quantile(0.997)] = '9+'
plt.figure(figsize=(15,10))
sns.countplot(data['kills'].astype('str').sort_values())
plt.title("Kill Count",fontsize=15)
plt.show()

# %%
groupByKills = train_dataset1.groupby('kills')
groupByKills.size()
# Out:
# kills
# 0     2529721
# 1      928079
# 2      472466
# 3      232441
# 4      124543
# 5       66577
# 6       37960
# 7       21816
# 8       12779
# 9        7644
# 10       4599
# 11       2799
# 12       1755
# 13       1137
# 14        757
# 15        484
# 16        325
# 17        234
# 18        165
# 19        112
# 20        109
# 21         70
# 22         77
# 23         47
# 24         44
# 25         27
# 26         27
# 27         21
# 28         22
# 29         13
# 30         13
# 31         13
# 32          4
# 33         12
# 34          5
# 35          7
# 36          8
# 37          5
# 38          7
# 39          4
# 40          4
# 41          5
# 42          3
# 43          3
# 44          2
# 45          1
# 46          2
# 47          1
# 48          1
# 49          1
# 50          1
# 53          4
# 55          2
# 56          2
# 57          2
# 65          1
# 66          1
# 72          1
# dtype: int64

# %%
type(groupByKills.size())
# Out:
# pandas.core.series.Series

# %%
# type(groupByKills) # tip #

# %%
#data again, important 
data = train_dataset1.copy()

# %%
plt.figure(figsize=(20,10))
plt.title("Kills",fontsize=15)
sns.distplot(data['kills'])
plt.show()
# Out:
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### What about damage?

# %%
data['damageDealt'].describe()
# Out:
# count    4.446965e+06
# mean     1.307172e+02
# std      1.707806e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.424000e+01
# 75%      1.860000e+02
# max      6.616000e+03
# Name: damageDealt, dtype: float64

# %%
# 0 KILLS
no_kills = data[data['kills']==0]

# %%
plt.figure(figsize=(15,10))
plt.title("Damage Dealt by 0 killers",fontsize=15)
sns.distplot(no_kills['damageDealt'])
plt.show()

# %%
one_kill = data[data['kills']==1]
plt.figure(figsize=(15,10))
i = 1
plt.title("Damage Dealt by " + str(i) +" killers",fontsize=15)
sns.distplot(one_kill['damageDealt'])
plt.show()

# %%
kills_index = groupByKills.size().index
# kills_index
for i in kills_index:
    kill_index = data[data['kills']==i]
    plt.figure(figsize=(15,10))
    plt.title("Damage Dealt by " + str(i) +" killers",fontsize=15)
    sns.distplot(kill_index['damageDealt'])
    plt.show()
# Out:
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
plt.figure(figsize=(25,10))
plt.title("winPlacePerc",fontsize=15)
sns.distplot(data['winPlacePerc'])
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.title("kills",fontsize=15)
sns.distplot(data['kills'])
plt.show()

# %%
sns.jointplot(x="winPlacePerc", y="kills", data=train_dataset1, height=10, ratio=3, color="b")
plt.show()

# %%
kills = train_dataset1.copy()

kills['killsCategoriesCustom'] = pd.cut(kills['kills'], [-1, 0, 1, 2, 3, 4], labels=['0_kills','1_kills', '2_kills', '3_kills', '4_kills'])

plt.figure(figsize=(15,8))
sns.boxplot(x="killsCategoriesCustom", y="winPlacePerc", data=kills)
plt.show()

kills['killsCategoriesCustom'] = pd.cut(kills['kills'], [4, 5, 6, 7, 8, 9], labels=['5_kills','6_kills', '7_kills', '8_kills', '9_kills'])

plt.figure(figsize=(15,8))
sns.boxplot(x="killsCategoriesCustom", y="winPlacePerc", data=kills)
plt.show()

# %%
    kills['killsCategoriesCustom'] = pd.cut(kills['kills'], [10, 11, 12, 13, 14, 15], labels=['10_kills','11_kills', '12_kills', '13_kills', '14_kills'])

plt.figure(figsize=(15,8))
sns.boxplot(x="killsCategoriesCustom", y="winPlacePerc", data=kills)
plt.show()

# %%
# data = train_dataset1.copy()
no_kills = data[data['kills']==0]
no_kills_win = no_kills[no_kills['winPlacePerc']==1]
print("{} players ({:.4f}%) have won without a single kill (kills=> Number of enemy players killed.)!".format(len(no_kills_win), 100*len(no_kills_win)/len(train_dataset1)))

data1 = train_dataset1[train_dataset1['damageDealt'] == 0].copy()
no_kills_win_damage0 = data1[data1['winPlacePerc']==1]
print("{} players ({:.4f}%) have won without dealing damage!".format(len(no_kills_win_damage0), 100*len(no_kills_win_damage0)/len(train_dataset1)))

winPlacePerc1 = data[data['winPlacePerc']==1]
print("{} players ({:.4f}%) have won!".format(len(winPlacePerc1), 100*len(winPlacePerc1)/len(train_dataset1)))
# Out:
# 16666 players (0.3748%) have won without a single kill (kills=> Number of enemy players killed.)!
# 4770 players (0.1073%) have won without dealing damage!
# 127573 players (2.8688%) have won!

# %%
winPlacePerc1['kills'].describe()
# Out:
# count    127573.000000
# mean          3.632994
# std           3.173797
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           5.000000
# max          72.000000
# Name: kills, dtype: float64

# %%
train_dataset1['numGroups'].describe()
print("15% of people have {} numGroups or less.".format(train_dataset1['numGroups'].quantile(0.25)))
print("50% of people have {} numGroups or less.".format(train_dataset1['numGroups'].quantile(0.50)))
print("Mean of people have {} numGroups or less.".format(train_dataset1['numGroups'].mean()))
# Out:
# 15% of people have 27.0 numGroups or less.
# 50% of people have 30.0 numGroups or less.
# Mean of people have 43.007602038693804 numGroups or less.

# %%
plt.figure(figsize=(25,10))
plt.title("numGroups",fontsize=15)
sns.distplot(train_dataset1['numGroups'])
plt.show()
# numGroups - Number of groups we have data for in the match.

# %%
solos = train_dataset1[train_dataset1['numGroups']>50]
duos = train_dataset1[(train_dataset1['numGroups']>25) & (train_dataset1['numGroups']<=50)]
squads = train_dataset1[train_dataset1['numGroups']<=25]
print("There are {} ({:.2f}%) solo games".format(len(solos), 100*len(solos)/len(train_dataset1)))
print("There are {} ({:.2f}%) solo games".format(len(duos), 100*len(duos)/len(train_dataset1)))
print("There are {} ({:.2f}%) solo games".format(len(squads), 100*len(squads)/len(train_dataset1)))
# Out:
# There are 709111 (15.95%) solo games
# There are 3295326 (74.10%) solo games
# There are 442528 (9.95%) solo games

# %%
plt.figure(figsize=(15,10))
plt.title("solos",fontsize=15)
sns.distplot(solos['numGroups'])
plt.show()

# %% [markdown]
# # Modelling
# ## Linear Model

# %%
X = train_dataset1.iloc[:,3:-1].values
X.shape
# Out:
# (4446965, 25)

# %%
train_dataset['damageDealt'][0:5]
# Out:
# 0      0.00
# 1     91.47
# 2     68.00
# 3     32.90
# 4    100.00
# Name: damageDealt, dtype: float64

# %%
X[:,2][0:5]
# Out:
# array([0.0, 91.47, 68.0, 32.9, 100.0], dtype=object)

# %%
y = train_dataset.iloc[:,num_cols-1].values
y = np.array(y).reshape(-1,1)
y.shape
# Out:
# (4446966, 1)

# %%
y[0:5]
# Out:
# array([[0.4444],
#        [0.64  ],
#        [0.7755],
#        [0.1667],
#        [0.1875]])

# %%
train_dataset['winPlacePerc'][0:5]
# Out:
# 0    0.4444
# 1    0.6400
# 2    0.7755
# 3    0.1667
# 4    0.1875
# Name: winPlacePerc, dtype: float64

# %%
X[:,12][0:5]
# Out:
# array(['squad-fpp', 'squad-fpp', 'duo', 'squad-fpp', 'solo-fpp'],
#       dtype=object)

# %%
train_dataset['matchType'][0:5]
# Out:
# 0    squad-fpp
# 1    squad-fpp
# 2          duo
# 3    squad-fpp
# 4     solo-fpp
# Name: matchType, dtype: object

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:, 12] = labelencoder.fit_transform(X[:, 12])# i think
onehotencoder = OneHotEncoder(categorical_features = [12])
X = onehotencoder.fit_transform(X).toarray()
print(X.shape)
X = X[:, 1:] # remove the index 0
print(X.shape)
# Out:
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:363: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /Users/axeljeremy/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:385: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# (4446965, 40)
# (4446965, 39)

# %%
X[:,12][0:5]
# Out:
# array([0., 0., 0., 0., 1.])

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X)
#X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# Predicting the Test set results
y_pred = model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-67b8c7c0e11c> in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model.fit(X_train, y_train)
#       5
#       6 # Predicting the Test set results
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y, y_pred)
mse

# %%
from sklearn.metrics import mean_absolute_error
mae =  mean_absolute_error(y, y_pred)
mae

# %%
X_train.shape

# %%
#Backward Elimination
import statsmodels.formula.api as sm

#Add colummns of ones for x0
nX = np.append(arr =  np.ones((num_rows,1)).astype(int),  values = X_train, axis = 1)
nX.shape

# %%
#nX_optimal = nX[:,[0,1,2,3,4,5]]
model_ols = sm.OLS(endog =  y_train, exog = nX).fit()
print(model_ols.summary())
